# %%
data = [4, 347, 12,3429, 67]

# %%
second_max = float("-inf")
largest = float("-inf")
n = len(data)
for i in range(0,n):
    largest = max(data[i],largest)

# %%
print(largest)
# Out:
# 3429

# %%
largest =max(data)
print(largest)
# Out:
# 3429
